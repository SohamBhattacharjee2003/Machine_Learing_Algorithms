# %% [markdown]
# <a href="https://colab.research.google.com/github/SohamBhattacharjee2003/Machine_Learing_Algorithms/blob/main/Linear_Regration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import fetch_california_housing

# %%
fetch_california_housing()
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
import numpy as np
import pandas as pd

# %%
df = fetch_california_housing()

# %%
dataset = pd.DataFrame(df.data)

# %%
dataset.columns = df.feature_names

# %%
## Independent and Dependent Feature
x = dataset
y = df.target

# %%
y
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
## Train and Split
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.30,random_state=4)

# %%
x_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 7379   2.1473      41.0  3.416185   1.000000      1644.0  4.751445     33.97
# 16825  3.5250      34.0  4.296296   0.895062       398.0  2.456790     37.63
# 4424   1.5491      20.0  1.640000   0.680000        87.0  3.480000     34.06
# 17693  5.7078      17.0  5.395735   1.014218      1887.0  4.471564     37.28
# 19584  5.6945      36.0  6.191489   1.021277       124.0  2.638298     37.59
# ...       ...       ...       ...        ...         ...       ...       ...
# 16840  5.0479      22.0  5.135878   1.054962      3783.0  2.887786     37.63
# 11863  3.5962      36.0  6.095420   1.148855       632.0  2.412214     40.31
# 17093  2.7969      38.0  4.067010   1.028351       879.0  2.265464     37.48
# 8366   2.6734      26.0  4.238938   1.188053      2340.0  2.588496     33.97
# 17530  2.5673      48.0  3.683962   1.035377      1469.0  3.464623     37.35
#
#        Longitude
# 7379     -118.24
# ...

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()

# %%
x_train = scalar.fit_transform(x_train)

# %%
scalar.inverse_transform(x_train)
# Out:
# array([[   2.1473    ,   41.        ,    3.41618497, ...,    4.75144509,
#           33.97      , -118.24      ],
#        [   3.525     ,   34.        ,    4.2962963 , ...,    2.45679012,
#           37.63      , -122.49      ],
#        [   1.5491    ,   20.        ,    1.64      , ...,    3.48      ,
#           34.06      , -118.25      ],
#        ...,
#        [   2.7969    ,   38.        ,    4.06701031, ...,    2.26546392,
#           37.48      , -122.23      ],
#        [   2.6734    ,   26.        ,    4.23893805, ...,    2.58849558,
#           33.97      , -118.35      ],
#        [   2.5673    ,   48.        ,    3.68396226, ...,    3.46462264,
#           37.35      , -121.89      ]])

# %%
x_test = scalar.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
#cross validation
from sklearn.model_selection import cross_val_score

# %%
regression = LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
mse = cross_val_score(regression,x_train,y_train,scoring='neg_mean_squared_error',cv=5)

# %%
np.mean(mse)
# Out:
# np.float64(-0.5328095408152926)

# %%
##prediction
reg_pred = regression.predict(x_test)

# %%
reg_pred
# Out:
# array([2.05882934, 2.50156213, 1.61033727, ..., 2.27724788, 0.92397711,
#        2.73830676])

# %%
import seaborn as sns
sns.displot(reg_pred-y_test,kind='kde')

# %%
from sklearn.metrics import r2_score
score = r2_score(reg_pred,y_test)

# %%
score
# Out:
# 0.3324532744516978

# %%
score
# Out:
# 0.3324532744516978

# %%
# !git config --global user.name "SohamBhattacharjee2003"

# %%
# !git clone https://github.com/SohamBhattacharjee2003/Mac.git
# Out:
# Cloning into 'Mac'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git add .
# !git commit -m "Initial commit"
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !ls
# Out:
# sample_data

# %%
# !git add .
# !git commit -m "Initial commit"
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
